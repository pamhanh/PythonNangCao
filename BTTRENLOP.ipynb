# %%
import pyodbc
cnxn = pyodbc.connect("Driver={ODBC Driver 17 for SQL Server};"
"Server=DESKTOP-D2B2918\SQLEXPRESS;"
"Database=QuanLyNhaHang_PhamTheHaiAnh_VuMyAnh;"
"Trusted_Connection=yes;")

# %%
cursor = cnxn.cursor()
cursor.execute("SELECT * FROM BanAn")
for row in cursor:
    print(row)
# Out:
# (1, 'Bàn 1', 'Trống', 1)
# (2, 'Bàn 2', 'Trống', 1)
# (3, 'Bàn VIP', 'Trống', 2)
# (4, 'Bàn 4', 'Trống', 2)
# (5, 'Bàn 5', 'Trống', 2)
# (6, 'Bàn 6', 'Trống', 2)
# (7, 'Bàn 7', 'Trống', 2)
# (8, 'Bàn 8', 'Trống', 2)
# (9, 'Bàn 9', 'Trống', 2)
# (10, 'Bàn 10', 'Trống', 2)
# (11, 'Bàn 11', 'Trống', 2)
# (12, 'Bàn 12', 'Trống', 2)
# (13, 'Bàn 13', 'Trống', 2)
# (14, 'Bàn 14', 'Trống', 2)
# (15, 'Bàn 15', 'Trống', 2)
# (16, 'Bàn 16', 'Trống', 2)
# (17, 'Bàn 17', 'Trống', 2)
# (18, 'Bàn 18', 'Trống', 2)
# (19, 'Bàn 19', 'Trống', 2)
# (20, 'Bàn 20', 'Trống', 2)
# (21, 'Mang Về', 'Trống', 1)

# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'SQL Server Native Client 10.0', 'ODBC Driver 17 for SQL Server']

# %%
cursor = cnxn.cursor()
cursor.execute("SELECT count(*) from BanAn")
for row in cursor
    print(row(0))
# Out:
#   Cell In[26], line 3
#     for row in cursor
#                      ^
# SyntaxError: expected ':'
