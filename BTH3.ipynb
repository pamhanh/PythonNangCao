# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('D:\python\PythonNangCao\Vietnam_COVID-19_patient.csv')
df
# Out:
#         ID Gender   Age Nationality Detection Location Treatment Location  \
# 0      BN1      M  66.0       China   Ho Chi Minh City   Ho Chi Minh City
# 1      BN2      M  28.0       China   Ho Chi Minh City   Ho Chi Minh City
# 2      BN3      F  25.0     Vietnam          Thanh Hoa          Thanh Hoa
# 3      BN4      M  29.0     Vietnam          Vinh Phuc          Vinh Phuc
# 4      BN5      F  23.0     Vietnam          Vinh Phuc          Vinh Phuc
# ..     ...    ...   ...         ...                ...                ...
# 283  BN284      F  30.0     Vietnam            Can Tho            Can Tho
# 284  BN285      F  30.0     Vietnam            Can Tho            Can Tho
# 285  BN286      F  23.0     Vietnam            Can Tho            Can Tho
# 286  BN287      M  28.0     Vietnam            Can Tho            Can Tho
# 287  BN288      F  32.0     Vietnam            Can Tho            Can Tho
#
#                                               Hospital Confirmed Date  \
# ...

# %%
plt.figure(figsize=(6, 6))
gender_counts = df['Gender'].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Tỉ lệ bệnh nhân Nam/Nữ')
plt.show()

# %% [markdown]
# Số lượng bệnh nhân theo tháng (Tháng 1 - 5)

# %%
#Chuyển str thành số
df['Confirmed Date'] = pd.to_datetime(df['Confirmed Date'], format='%m/%d/%y', errors='coerce')
df['Month'] = df['Confirmed Date'].dt.month
#Vẽ biểu đồ
plt.figure(figsize=(8, 5))
month_counts = df_months['Month'].value_counts().sort_index()
plt.bar(month_counts.index.astype(int).astype(str), month_counts.values, color='skyblue')
plt.xlabel('Tháng')
plt.ylabel('Số lượng ca nhiễm')
plt.title('Số lượng bệnh nhân Tháng 1 - Tháng 5')
plt.show()

# %% [markdown]
# C

# %%
plt.figure(figsize=(10, 6))
top_hospitals = df['Hospital'].value_counts().head(10)
plt.barh(top_hospitals.index, top_hospitals.values, color='salmon')
plt.gca().invert_yaxis()
plt.title('Top 10 bệnh viện có nhiều bệnh nhân nhất')
plt.tight_layout() # Tránh bị đè chữ ở trục Y
plt.show()

# %%
d

# %%
plt.figure(figsize=(10, 6))
top_locations = df['Treatment Location'].value_counts().head(10)
plt.barh(top_locations.index, top_locations.values, color='lightgreen')
plt.gca().invert_yaxis()
plt.title('Top 10 tỉnh thành có nhiều bệnh nhân nhất')
plt.tight_layout()
plt.show()

# %% [markdown]
# e

# %%
df['Confirmed Date'] = pd.to_datetime(df['Confirmed Date'], format='%m/%d/%y', errors='coerce')
df['Month'] = df['Confirmed Date'].dt.month
plt.figure(figsize=(8, 5))
plt.plot(month_counts.index.astype(str), month_counts.values, marker='o', linestyle='-', color='red')
plt.xlabel('Tháng')
plt.ylabel('Số lượng bệnh nhân')
plt.title('Diễn biến số lượng bệnh nhân theo tháng')
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# f

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df.index, df['Age'], alpha=0.6, color='purple', s=10)
plt.ylabel('Độ tuổi')
plt.xlabel('Số thứ tự bệnh nhân')
plt.title('Phân bổ độ tuổi bệnh nhân (Scatter Plot)')
plt.show()

# %% [markdown]
# g

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Age'].dropna(), bins=20, color='orange', edgecolor='black')
plt.xlabel('Độ tuổi')
plt.ylabel('Số lượng bệnh nhân')
plt.title('Phân bổ độ tuổi bệnh nhân (Histogram)')
plt.show()

# %% [markdown]
# Bài 2

# %%
df = pd.read_json('LazadaProductData (1).json')
df
# Out:
#        p_brand                        p_cate  \
# 0         Dell          Máy vi tính & Laptop
# 1           HP          Máy vi tính & Laptop
# 2           HP          Máy vi tính & Laptop
# 3         Dell          Máy vi tính & Laptop
# 4      OnePlus          Máy vi tính & Laptop
# ...        ...                           ...
# 2485       OEM  Túi xách và Vali túi du lịch
# 2486       OEM  Túi xách và Vali túi du lịch
# 2487    Shalla  Túi xách và Vali túi du lịch
# 2488  No Brand  Túi xách và Vali túi du lịch
# 2489   BEE GEE  Túi xách và Vali túi du lịch
#
#                                                 p_image    p_mall  \
# 0     //vn-live-05.slatic.net/p/ab973a529b50491bb63a...      Mall
# 1     //vn-live-05.slatic.net/p/0fc9119358dc21cb9dcd...      Mall
# 2     //vn-live-05.slatic.net/p/1063855536ce9dfae5dc...      Mall
# 3     //vn-live-05.slatic.net/p/756f7f7aeb632324816e...  Non-Mall
# 4     //vn-live-05.slatic.net/p/ec69d1bd94b9e41f3f37...  Non-Mall
# ...

# %% [markdown]
# A

# %%
plt.figure(figsize=(10, 6))
cate_counts = df['p_cate'].value_counts()
bars = plt.bar(cate_counts.index, cate_counts.values, color='skyblue', edgecolor='black')
plt.xticks(rotation=45, ha='right')
pass

# %% [markdown]
# b

# %%
plt.figure(figsize=(12, 6))
top_10_rating = df.nlargest(10, 'p_rating').copy()
plt.barh(top_10_rating['s_name'], top_10_rating['p_rating'], color='lightgreen', edgecolor='black')
plt.gca().invert_yaxis() # Đảo trục Y để Top 1 nằm trên cùng

# %%
cate_counts = df['p_cate'].value_counts()#Thống kê các sản phẩm ra
plt.figure(figsize=(10, 8))
plt.pie(cate_counts, labels=cate_counts.index, autopct='%1.1f%%', startangle=140)#Tính phẩn trăm và in ra biểu đồ
pass

# %% [markdown]
# Bài 3

# %%
df = pd.read_xml('netflix-data-1-1.xml')
df
# Out:
#    document-statistic                                          generator  \
# 0                 NaN  LibreOffice/7.3.7.2$Linux_X86_64 LibreOffice_p...
# 1                 NaN                                               None
# 2                 NaN                                               None
# 3                 NaN                                               None
# 4                 NaN                                               None
# 5                 NaN                                               None
# 6                 NaN                                               None
# 7                 NaN                                               None
#
#   config-item-set script  font-face default-style number-style  style  \
# 0            None   None        NaN          None         None   None
# 1           \n      None        NaN          None         None   None
# 2            None  \n           NaN          None         None   None
# ...
